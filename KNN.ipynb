# %% [markdown]
# <a href="https://colab.research.google.com/github/Armin-HassanzadehHassanabad/Machine-Learning/blob/main/KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import io
from google.colab import files

# %%
uploaded = files.upload()
df = pd.read_csv(io.BytesIO(uploaded[list(uploaded.keys())[0]]))
# Out:
#      <input type="file" id="files-d6d3fde1-fbd6-4f79-adc0-703fb3b3456a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d6d3fde1-fbd6-4f79-adc0-703fb3b3456a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = df.fillna(0)

# %%
x = df.drop("c" , axis = 1)
y = df.c

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_predict , cross_val_score
KNN = KNeighborsClassifier(n_neighbors = 7, weights = "distance")
scores = cross_val_score(KNN, x , y , cv =10 , scoring = 'accuracy').mean()
scores
# Out:
# np.float64(0.6417514124293785)

# %%
from sklearn import metrics
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
k_range = list(range(1,30))
scores = []
for i in k_range:
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
plt.plot(k_range, scores)
plt.xlabel('K value for KNN')
plt.ylabel('Accuracy Score')
plt.title('Accuracy Scores for Values of kNN')
# Out:
# Text(0.5, 1.0, 'Accuracy Scores for Values of kNN')
